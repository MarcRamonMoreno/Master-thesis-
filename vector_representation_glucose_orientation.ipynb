# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap
import matplotlib.colors as mcolors

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_TOP_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 7

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]

# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]

# Extract the data from the sets
xh_0_01 = [set_[:2] for set_ in xh_0_01_sets]
yh_0_01 = [set_[:2] for set_ in yh_0_01_sets]
xt_0_01 = [set_[:2] for set_ in xt_0_01_sets]
yt_0_01 = [set_[:2] for set_ in yt_0_01_sets]
angle_0_01 = [set_[:2] for set_ in angle_0_01_sets]

xh_100_01 = [set_[:2] for set_ in xh_100_01_sets]
yh_100_01 = [set_[:2] for set_ in yh_100_01_sets]
xt_100_01 = [set_[:2] for set_ in xt_100_01_sets]
yt_100_01 = [set_[:2] for set_ in yt_100_01_sets]
angle_100_01 = [set_[:2] for set_ in angle_100_01_sets]


# Remove the last element from sets with more than 2 elements
#xh_0_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in xh_0_01_sets]
#yh_0_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in yh_0_01_sets]
#xt_0_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in xt_0_01_sets]
#yt_0_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in yt_0_01_sets]
#angle_0_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in angle_0_01_sets]

#xh_100_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in xh_100_01_sets]
#yh_100_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in yh_100_01_sets]
#xt_100_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in xt_100_01_sets]
#yt_100_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in yt_100_01_sets]
#angle_100_01 = [set_[:2] if len(set_) > 2 else set_ for set_ in angle_100_01_sets]

# Select the two elements in the middle of each set
#xh_0_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in xh_0_01_sets]
#yh_0_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in yh_0_01_sets]
#xt_0_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in xt_0_01_sets]
#yt_0_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in yt_0_01_sets]
#angle_0_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in angle_0_01_sets]

#xh_100_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in xh_100_01_sets]
#yh_100_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in yh_100_01_sets]
#xt_100_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in xt_100_01_sets]
#yt_100_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in yt_100_01_sets]
#angle_100_01 = [set_[len(set_) // 2 - 1: len(set_) // 2 + 1] if len(set_) > 2 else set_ for set_ in angle_100_01_sets]

arr = 0
element = 0
tg = np.nanmax(angle_100_01)
# Iterate over each array
for array in angle_100_01:
    # Access the elements of the array
    element = 0
    for value in array:
        #print(value)
        if value == tg:
            #print(arr)
            #print(element)
            #print(tg)
            #xh_0_01[in_arr][in_el] = np.nan
            #xt_0_01[in_arr][in_el] = np.nan
            #yh_0_01[in_arr][in_el] = np.nan
            #yt_0_01[in_arr][in_el] = np.nan
            #angle_0_01[in_arr][in_el] = np.nan
            
            xh_100_01[arr][element] = np.nan
            xt_100_01[arr][element] = np.nan
            yh_100_01[arr][element] = np.nan
            yt_100_01[arr][element] = np.nan
            angle_100_01[arr][element] = np.nan
            break
        else:
            element += 1        
    arr += 1

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000','#90EE90' ,'#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=2)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-30, 30])  # Adjust x limits
ax1.set_ylim([-30, 30])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')
#ax1.set_title('Time = 0.01 ns')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=2)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-32, 27])  # Adjust x limits
ax2.set_ylim([-30, 30])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')
#ax2.set_title('Time = 100.01')


# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.3)

# Save the plot figure as a .png file
plt.savefig('Tip4_inner_face_TOP_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000','#90EE90' ,'#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=2)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-23, 23])  # Adjust x limits
ax1.set_ylim([-20, 20])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')
#ax1.set_title('Time = 0.01 ns')

# Plot the heatmap for time = 100.01
image = plt.imread('Orientation_clipped.png')
# Get the dimensions of the image
height, width, _ = image.shape

# Calculate the extent to center the image at (0,0)
extent = [-width/27, width/27, -height/27, height/27]

# Create a figure and plot the image
ax2.imshow(image, extent=extent)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-23, 23])  # Adjust x limits
ax2.set_ylim([-20, 20])  # Adjust y limits
#cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
#cbar2.set_label('Alignment angle (º)')
#ax2.set_title('Time = 100.01')


# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.3)

# Save the plot figure as a .png file
plt.savefig('Cellulose_chain_alingment_representation.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_TOP_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]

# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]

# Extract the data from the sets
xh_0_01 = [set_[-2:] for set_ in xh_0_01_sets]
yh_0_01 = [set_[-2:] for set_ in yh_0_01_sets]
xt_0_01 = [set_[-2:] for set_ in xt_0_01_sets]
yt_0_01 = [set_[-2:] for set_ in yt_0_01_sets]
angle_0_01 = [set_[-2:] for set_ in angle_0_01_sets]

xh_100_01 = [set_[-2:] for set_ in xh_100_01_sets]
yh_100_01 = [set_[-2:] for set_ in yh_100_01_sets]
xt_100_01 = [set_[-2:] for set_ in xt_100_01_sets]
yt_100_01 = [set_[-2:] for set_ in yt_100_01_sets]
angle_100_01 = [set_[-2:] for set_ in angle_100_01_sets]

del xh_100_01[-2]
del yh_100_01[-2]
del xt_100_01[-2]
del yt_100_01[-2]
del angle_100_01[-2]

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000','#90EE90' ,'#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=2)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-30, 30])  # Adjust x limits
ax1.set_ylim([-30, 30])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')
#ax1.set_title('Time = 0.01 ns')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=2)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-32, 27])  # Adjust x limits
ax2.set_ylim([-30, 30])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')
#ax2.set_title('Time = 100.01')


# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.3)

# Save the plot figure as a .png file
plt.savefig('Tip4_outer_face_TOP_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_MIDDLE_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]

# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]

# Extract the data from the sets
xh_0_01 = [set_[:2] for set_ in xh_0_01_sets]
yh_0_01 = [set_[:2] for set_ in yh_0_01_sets]
xt_0_01 = [set_[:2] for set_ in xt_0_01_sets]
yt_0_01 = [set_[:2] for set_ in yt_0_01_sets]
angle_0_01 = [set_[:2] for set_ in angle_0_01_sets]

xh_100_01 = [set_[:2] for set_ in xh_100_01_sets]
yh_100_01 = [set_[:2] for set_ in yh_100_01_sets]
xt_100_01 = [set_[:2] for set_ in xt_100_01_sets]
yt_100_01 = [set_[:2] for set_ in yt_100_01_sets]
angle_100_01 = [set_[:2] for set_ in angle_100_01_sets]

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000','#90EE90' ,'#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=2)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-30, 30])  # Adjust x limits
ax1.set_ylim([-30, 30])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')
#ax1.set_title('Time = 0.01 ns')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=2)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-30, 30])  # Adjust x limits
ax2.set_ylim([-30, 30])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')
#ax2.set_title('Time = 100.01')


# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.3)

# Save the plot figure as a .png file
plt.savefig('Tip4_inner_face_MIDDLE_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_MIDDLE_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]

# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]

# Extract the data from the sets
xh_0_01 = [set_[-2:] for set_ in xh_0_01_sets]
yh_0_01 = [set_[-2:] for set_ in yh_0_01_sets]
xt_0_01 = [set_[-2:] for set_ in xt_0_01_sets]
yt_0_01 = [set_[-2:] for set_ in yt_0_01_sets]
angle_0_01 = [set_[-2:] for set_ in angle_0_01_sets]

xh_100_01 = [set_[-2:] for set_ in xh_100_01_sets]
yh_100_01 = [set_[-2:] for set_ in yh_100_01_sets]
xt_100_01 = [set_[-2:] for set_ in xt_100_01_sets]
yt_100_01 = [set_[-2:] for set_ in yt_100_01_sets]
angle_100_01 = [set_[-2:] for set_ in angle_100_01_sets]

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000','#90EE90' ,'#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=2)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-30, 30])  # Adjust x limits
ax1.set_ylim([-30, 30])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')
#ax1.set_title('Time = 0.01 ns')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=2)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-30, 30])  # Adjust x limits
ax2.set_ylim([-30, 30])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')
#ax2.set_title('Time = 100.01')


# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.3)

# Save the plot figure as a .png file
plt.savefig('Tip4_outer_face_MIDDLE_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_BOTTOM_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]

# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]

# Extract the data from the sets
xh_0_01 = [set_[:2] for set_ in xh_0_01_sets]
yh_0_01 = [set_[:2] for set_ in yh_0_01_sets]
xt_0_01 = [set_[:2] for set_ in xt_0_01_sets]
yt_0_01 = [set_[:2] for set_ in yt_0_01_sets]
angle_0_01 = [set_[:2] for set_ in angle_0_01_sets]

xh_100_01 = [set_[:2] for set_ in xh_100_01_sets]
yh_100_01 = [set_[:2] for set_ in yh_100_01_sets]
xt_100_01 = [set_[:2] for set_ in xt_100_01_sets]
yt_100_01 = [set_[:2] for set_ in yt_100_01_sets]
angle_100_01 = [set_[:2] for set_ in angle_100_01_sets]

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000','#90EE90' ,'#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=2)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-30, 30])  # Adjust x limits
ax1.set_ylim([-30, 30])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')
#ax1.set_title('Time = 0.01 ns')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=2)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-32, 27])  # Adjust x limits
ax2.set_ylim([-30, 30])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')
#ax2.set_title('Time = 100.01')


# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.3)

# Save the plot figure as a .png file
plt.savefig('Tip4_inner_face_BOTTOM_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_BOTTOM_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]

# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]

# Extract the data from the sets
xh_0_01 = [set_[-2:] for set_ in xh_0_01_sets]
yh_0_01 = [set_[-2:] for set_ in yh_0_01_sets]
xt_0_01 = [set_[-2:] for set_ in xt_0_01_sets]
yt_0_01 = [set_[-2:] for set_ in yt_0_01_sets]
angle_0_01 = [set_[-2:] for set_ in angle_0_01_sets]

xh_100_01 = [set_[-2:] for set_ in xh_100_01_sets]
yh_100_01 = [set_[-2:] for set_ in yh_100_01_sets]
xt_100_01 = [set_[-2:] for set_ in xt_100_01_sets]
yt_100_01 = [set_[-2:] for set_ in yt_100_01_sets]
angle_100_01 = [set_[-2:] for set_ in angle_100_01_sets]
arr = 0
element = 0
tg = np.nanmax(angle_100_01)
# Iterate over each array
for array in angle_100_01:
    # Access the elements of the array
    element = 0
    for value in array:
        #print(value)
        if value == tg:
            print(arr)
            print(element)
            print(tg)
            #xh_0_01[in_arr][in_el] = np.nan
            #xt_0_01[in_arr][in_el] = np.nan
            #yh_0_01[in_arr][in_el] = np.nan
            #yt_0_01[in_arr][in_el] = np.nan
            #angle_0_01[in_arr][in_el] = np.nan
            
            xh_100_01[arr][element] = np.nan
            xt_100_01[arr][element] = np.nan
            yh_100_01[arr][element] = np.nan
            yt_100_01[arr][element] = np.nan
            angle_100_01[arr][element] = np.nan
            break
        else:
            element += 1        
    arr += 1
# Out:
# 0
# 1
# 164.5680449579669

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000','#90EE90' ,'#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=2)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-30, 30])  # Adjust x limits
ax1.set_ylim([-30, 30])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')
#ax1.set_title('Time = 0.01 ns')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=2)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-30, 30])  # Adjust x limits
ax2.set_ylim([-30, 30])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')
#ax2.set_title('Time = 100.01')


# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.3)

# Save the plot figure as a .png file
plt.savefig('Tip4_outer_face_BOTTOM_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_TOP_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
#zh = data[:, 3]
xt = data[:, 4]
yt = data[:, 5]
#zt = data[:, 6]
angle = data[:, 7]

# Filter the data for time == 0.01
mask_initial = (time == 0.01)
xh_initial = xh[mask_initial][:8]
yh_initial = yh[mask_initial][:8]
xt_initial = xt[mask_initial][:8]
yt_initial = yt[mask_initial][:8]
angle_initial = angle[mask_initial][:8]

# Filter the data for time == 100.01
mask_filtered = (time == 100.01)
xh_filtered = xh[mask_filtered][:8]
yh_filtered = yh[mask_filtered][:8]
xt_filtered = xt[mask_filtered][:8]
yt_filtered = yt[mask_filtered][:8]
angle_filtered = angle[mask_filtered][:8]

# Create a 2D plot with arrows
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121)
ax1.quiver(xt_filtered, yt_filtered, xh_filtered - xt_filtered, yh_filtered - yt_filtered,
           angle_filtered, cmap='plasma')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_xlim([-30, 30])
ax1.set_ylim([-30, 30])
cbar = plt.colorbar(ax1.collections[0])
cbar.set_label('Alignment angle (º)')

ax2 = fig.add_subplot(122)
ax2.quiver(xt_initial, yt_initial, xh_initial - xt_initial, yh_initial - yt_initial,
           angle_initial, cmap='plasma')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([-30, 30])
ax2.set_ylim([-30, 30])
cbar = plt.colorbar(ax2.collections[0])
cbar.set_label('Alignment angle (º)')

plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_MIDDLE_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
x = data[:, 1]
y = data[:, 2]
z = data[:, 3]
angle = data[:, 7]

z_threshold=((np.max(z)-np.min(z))/2)

#print(z_threshold)
#print(np.min(z))
#print(np.max(z))

# Filter the data based on time and z coordinate
#mask = (z >= z_threshold) & (time == 100.01)
mask = (time == 100.0)
x_filtered = x[mask]
y_filtered = y[mask]
z_filtered = z[mask]
angle_filtered = angle[mask]
#print(z_filtered)
# Filter the data based on time and z coordinate
#mask = (z >= z_threshold) & (time == 0.01)
mask = (time == 0.01)
x_initial = x[mask]
y_initial = y[mask]
z_initial = z[mask]
angle_initial = angle[mask]

# %%
# Create a 3D plot
colors = ['#0700C7', '#0096FF', '#00FFDB', '#00E000', '#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)
fig = plt.figure(figsize=(12, 6))

ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(x_filtered, y_filtered, z_filtered,c=angle_filtered, cmap=cmap)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_xlim([-30, 30])  # Set x-axis limits
ax1.set_ylim([-30, 30])  # Set y-axis limits

ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(x_initial, y_initial, z_initial,c=angle_initial, cmap=cmap)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([-30, 30])  # Set x-axis limits
ax2.set_ylim([-30, 30])  # Set y-axis limits

# Remove Z-axis
ax1.zaxis.line.set_lw(0)
ax1.set_zticks([])
ax2.zaxis.line.set_lw(0)
ax2.set_zticks([])

# Set the initial view angles for both subplots
ax1.view_init(elev=90, azim=0)
ax2.view_init(elev=90, azim=0)

# Add a colorbar
cbar = fig.colorbar(ax1.collections[0])
cbar.set_label('Alignment angle (º)')
cbarinit = fig.colorbar(ax2.collections[0])
cbarinit.set_label('Alignment angle (º)')

plt.subplots_adjust(wspace=0.1)

# Save the plot figure as a .png file
#plt.savefig('Tip4_outer_face_MIDDLE_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

# Show the plot
plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_BOTTOM_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]


# Extract the data from the sets
xh_0_01 = [set_[-2:] for set_ in xh_0_01_sets]
yh_0_01 = [set_[-2:] for set_ in yh_0_01_sets]
xt_0_01 = [set_[-2:] for set_ in xt_0_01_sets]
yt_0_01 = [set_[-2:] for set_ in yt_0_01_sets]
angle_0_01 = [set_[-2:] for set_ in angle_0_01_sets]

# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_TOP_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]


time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8



# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]


xh_100_01 = [set_[-2:] for set_ in xh_100_01_sets]
yh_100_01 = [set_[-2:] for set_ in yh_100_01_sets]
xt_100_01 = [set_[-2:] for set_ in xt_100_01_sets]
yt_100_01 = [set_[-2:] for set_ in yt_100_01_sets]
angle_100_01 = [set_[-2:] for set_ in angle_100_01_sets]

del xh_100_01[-2]
del yh_100_01[-2]
del xt_100_01[-2]
del yt_100_01[-2]
del angle_100_01[-2]

# Load the data from the .dat file
data = np.loadtxt('Vac_eq_orientations_TOP_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]


time_100_02 = 100.0
indices_100_02 = np.where(time == time_100_02)

xh_100_02 = xh[indices_100_02]
yh_100_02 = yh[indices_100_02]
angle_100_02 = angle[indices_100_02]

time_100_02 = 100.0
indices_100_02 = np.where(time == time_100_02)

xt_100_02 = xt[indices_100_02]
yt_100_02 = yt[indices_100_02]

set_size = 8


# Divide xh_100_01 into sets
xh_100_02_sets = [xh_100_02[i:i+set_size][::1] for i in range(0, len(xh_100_02), set_size)]
# Divide yh_100_01 into sets
yh_100_02_sets = [yh_100_02[i:i+set_size][::1] for i in range(0, len(yh_100_02), set_size)]
# Divide xt_100_01 into sets
xt_100_02_sets = [xt_100_02[i:i+set_size][::1] for i in range(0, len(xt_100_02), set_size)]
# Divide yt_100_01 into sets
yt_100_02_sets = [yt_100_02[i:i+set_size][::1] for i in range(0, len(yt_100_02), set_size)]
# Divide angle_100_01 into sets
angle_100_02_sets = [angle_100_02[i:i+set_size][::1] for i in range(0, len(angle_100_02), set_size)]
#print(xh_100_01_sets)


xh_100_02 = [set_[-2:] for set_ in xh_100_02_sets]
yh_100_02 = [set_[-2:] for set_ in yh_100_02_sets]
xt_100_02 = [set_[-2:] for set_ in xt_100_02_sets]
yt_100_02 = [set_[-2:] for set_ in yt_100_02_sets]
angle_100_02 = [set_[-2:] for set_ in angle_100_02_sets]

del xh_100_02[-2]
del yh_100_02[-2]
del xt_100_02[-2]
del yt_100_02[-2]
del angle_100_02[-2]

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000', '#90EE90', '#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=30)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-25, 25])  # Adjust x limits
ax1.set_ylim([-20, 20])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=30)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-30, 30])  # Adjust x limits
ax2.set_ylim([-25, 25])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')

# Plot the heatmap for time = 200.01
ax3.quiver(np.array(xt_100_02), np.array(yt_100_02),
           np.array(xh_100_02) - np.array(xt_100_02),
           np.array(yh_100_02) - np.array(yt_100_02),
           np.array(angle_100_02), cmap=cmap, scale=30, linewidth=30)
ax3.set_xlabel('x (A)')
ax3.set_ylabel('y (A)')
ax3.set_xlim([-25, 25])  # Adjust x limits
ax3.set_ylim([-25, 25])  # Adjust y limits
cbar3 = plt.colorbar(ax3.collections[0], ax=ax3, orientation='vertical')
cbar3.set_label('Alignment angle (º)')

# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.2)

# Save the plot figure as a .png file
plt.savefig('TOP_Comparison_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_BOTTOM_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]


# Extract the data from the sets
xh_0_01 = [set_[-2:] for set_ in xh_0_01_sets]
yh_0_01 = [set_[-2:] for set_ in yh_0_01_sets]
xt_0_01 = [set_[-2:] for set_ in xt_0_01_sets]
yt_0_01 = [set_[-2:] for set_ in yt_0_01_sets]
angle_0_01 = [set_[-2:] for set_ in angle_0_01_sets]

# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_MIDDLE_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]


time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8



# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]


xh_100_01 = [set_[:2] for set_ in xh_100_01_sets]
yh_100_01 = [set_[:2] for set_ in yh_100_01_sets]
xt_100_01 = [set_[:2] for set_ in xt_100_01_sets]
yt_100_01 = [set_[:2] for set_ in yt_100_01_sets]
angle_100_01 = [set_[:2] for set_ in angle_100_01_sets]

#del xh_100_01[-2]
#del yh_100_01[-2]
#del xt_100_01[-2]
#del yt_100_01[-2]
#del angle_100_01[-2]

# Load the data from the .dat file
data = np.loadtxt('Vac_eq_orientations_MIDDLE_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]


time_100_02 = 100.0
indices_100_02 = np.where(time == time_100_02)

xh_100_02 = xh[indices_100_02]
yh_100_02 = yh[indices_100_02]
angle_100_02 = angle[indices_100_02]

time_100_02 = 100.0
indices_100_02 = np.where(time == time_100_02)

xt_100_02 = xt[indices_100_02]
yt_100_02 = yt[indices_100_02]

set_size = 8


# Divide xh_100_01 into sets
xh_100_02_sets = [xh_100_02[i:i+set_size][::1] for i in range(0, len(xh_100_02), set_size)]
# Divide yh_100_01 into sets
yh_100_02_sets = [yh_100_02[i:i+set_size][::1] for i in range(0, len(yh_100_02), set_size)]
# Divide xt_100_01 into sets
xt_100_02_sets = [xt_100_02[i:i+set_size][::1] for i in range(0, len(xt_100_02), set_size)]
# Divide yt_100_01 into sets
yt_100_02_sets = [yt_100_02[i:i+set_size][::1] for i in range(0, len(yt_100_02), set_size)]
# Divide angle_100_01 into sets
angle_100_02_sets = [angle_100_02[i:i+set_size][::1] for i in range(0, len(angle_100_02), set_size)]
#print(xh_100_01_sets)


xh_100_02 = [set_[:2] for set_ in xh_100_02_sets]
yh_100_02 = [set_[:2] for set_ in yh_100_02_sets]
xt_100_02 = [set_[:2] for set_ in xt_100_02_sets]
yt_100_02 = [set_[:2] for set_ in yt_100_02_sets]
angle_100_02 = [set_[:2] for set_ in angle_100_02_sets]

#del xh_100_02[-2]
#del yh_100_02[-2]
#del xt_100_02[-2]
#del yt_100_02[-2]
#del angle_100_02[-2]

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000', '#90EE90', '#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=30)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-25, 25])  # Adjust x limits
ax1.set_ylim([-20, 20])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=30)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-30, 30])  # Adjust x limits
ax2.set_ylim([-25, 25])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')

# Plot the heatmap for time = 200.01
ax3.quiver(np.array(xt_100_02), np.array(yt_100_02),
           np.array(xh_100_02) - np.array(xt_100_02),
           np.array(yh_100_02) - np.array(yt_100_02),
           np.array(angle_100_02), cmap=cmap, scale=30, linewidth=30)
ax3.set_xlabel('x (A)')
ax3.set_ylabel('y (A)')
ax3.set_xlim([-25, 25])  # Adjust x limits
ax3.set_ylim([-25, 25])  # Adjust y limits
cbar3 = plt.colorbar(ax3.collections[0], ax=ax3, orientation='vertical')
cbar3.set_label('Alignment angle (º)')

# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.2)

# Save the plot figure as a .png file
plt.savefig('MIDDLE_Comparison_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()

# %%
# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_BOTTOM_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xh_0_01 = xh[indices_0_01]
yh_0_01 = yh[indices_0_01]
angle_0_01 = angle[indices_0_01]

time_0_01 = 0.01
indices_0_01 = np.where(time == time_0_01)

xt_0_01 = xt[indices_0_01]
yt_0_01 = yt[indices_0_01]

set_size = 8

# Divide xh_0_01 into sets
xh_0_01_sets = [xh_0_01[i:i+set_size][::1] for i in range(0, len(xh_0_01), set_size)]
# Divide yh_0_01 into sets
yh_0_01_sets = [yh_0_01[i:i+set_size][::1] for i in range(0, len(yh_0_01), set_size)]
# Divide xt_0_01 into sets
xt_0_01_sets = [xt_0_01[i:i+set_size][::1] for i in range(0, len(xt_0_01), set_size)]
# Divide yt_0_01 into sets
yt_0_01_sets = [yt_0_01[i:i+set_size][::1] for i in range(0, len(yt_0_01), set_size)]
# Divide angle_0_01 into sets
angle_0_01_sets = [angle_0_01[i:i+set_size][::1] for i in range(0, len(angle_0_01), set_size)]


# Extract the data from the sets
xh_0_01 = [set_[-2:] for set_ in xh_0_01_sets]
yh_0_01 = [set_[-2:] for set_ in yh_0_01_sets]
xt_0_01 = [set_[-2:] for set_ in xt_0_01_sets]
yt_0_01 = [set_[-2:] for set_ in yt_0_01_sets]
angle_0_01 = [set_[-2:] for set_ in angle_0_01_sets]

# Load the data from the .dat file
data = np.loadtxt('Tip4_eq_orientations_BOTTOM_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]


time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xh_100_01 = xh[indices_100_01]
yh_100_01 = yh[indices_100_01]
angle_100_01 = angle[indices_100_01]

time_100_01 = 100.0
indices_100_01 = np.where(time == time_100_01)

xt_100_01 = xt[indices_100_01]
yt_100_01 = yt[indices_100_01]

set_size = 8



# Divide xh_100_01 into sets
xh_100_01_sets = [xh_100_01[i:i+set_size][::1] for i in range(0, len(xh_100_01), set_size)]
# Divide yh_100_01 into sets
yh_100_01_sets = [yh_100_01[i:i+set_size][::1] for i in range(0, len(yh_100_01), set_size)]
# Divide xt_100_01 into sets
xt_100_01_sets = [xt_100_01[i:i+set_size][::1] for i in range(0, len(xt_100_01), set_size)]
# Divide yt_100_01 into sets
yt_100_01_sets = [yt_100_01[i:i+set_size][::1] for i in range(0, len(yt_100_01), set_size)]
# Divide angle_100_01 into sets
angle_100_01_sets = [angle_100_01[i:i+set_size][::1] for i in range(0, len(angle_100_01), set_size)]


xh_100_01 = [set_[:2] for set_ in xh_100_01_sets]
yh_100_01 = [set_[:2] for set_ in yh_100_01_sets]
xt_100_01 = [set_[:2] for set_ in xt_100_01_sets]
yt_100_01 = [set_[:2] for set_ in yt_100_01_sets]
angle_100_01 = [set_[:2] for set_ in angle_100_01_sets]

#del xh_100_01[-2]
#del yh_100_01[-2]
#del xt_100_01[-2]
#del yt_100_01[-2]
#del angle_100_01[-2]

# Load the data from the .dat file
data = np.loadtxt('Vac_eq_orientations_BOTTOM_COORDS_TIME.dat')

# Extract the columns
time = data[:, 0]
xh = data[:, 1]
yh = data[:, 2]
xt = data[:, 4]
yt = data[:, 5]
angle = data[:, 7]


time_100_02 = 100.0
indices_100_02 = np.where(time == time_100_02)

xh_100_02 = xh[indices_100_02]
yh_100_02 = yh[indices_100_02]
angle_100_02 = angle[indices_100_02]

time_100_02 = 100.0
indices_100_02 = np.where(time == time_100_02)

xt_100_02 = xt[indices_100_02]
yt_100_02 = yt[indices_100_02]

set_size = 8


# Divide xh_100_01 into sets
xh_100_02_sets = [xh_100_02[i:i+set_size][::1] for i in range(0, len(xh_100_02), set_size)]
# Divide yh_100_01 into sets
yh_100_02_sets = [yh_100_02[i:i+set_size][::1] for i in range(0, len(yh_100_02), set_size)]
# Divide xt_100_01 into sets
xt_100_02_sets = [xt_100_02[i:i+set_size][::1] for i in range(0, len(xt_100_02), set_size)]
# Divide yt_100_01 into sets
yt_100_02_sets = [yt_100_02[i:i+set_size][::1] for i in range(0, len(yt_100_02), set_size)]
# Divide angle_100_01 into sets
angle_100_02_sets = [angle_100_02[i:i+set_size][::1] for i in range(0, len(angle_100_02), set_size)]
#print(xh_100_01_sets)


xh_100_02 = [set_[:2] for set_ in xh_100_02_sets]
yh_100_02 = [set_[:2] for set_ in yh_100_02_sets]
xt_100_02 = [set_[:2] for set_ in xt_100_02_sets]
yt_100_02 = [set_[:2] for set_ in yt_100_02_sets]
angle_100_02 = [set_[:2] for set_ in angle_100_02_sets]

#del xh_100_02[-2]
#del yh_100_02[-2]
#del xt_100_02[-2]
#del yt_100_02[-2]
#del angle_100_02[-2]

# %%
colors = ['#0700C7', '#0096FF', '#00FFDB', '#006400', '#00E000', '#90EE90', '#FFD700', '#FF6E00', '#C70000']
cmap = plt.cm.colors.ListedColormap(colors)

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))

# Plot the heatmap for time = 0.01
ax1.quiver(np.array(xt_0_01), np.array(yt_0_01),
           np.array(xh_0_01) - np.array(xt_0_01),
           np.array(yh_0_01) - np.array(yt_0_01),
           np.array(angle_0_01), cmap=cmap, scale=30, linewidth=30)
ax1.set_xlabel('x (A)')
ax1.set_ylabel('y (A)')
ax1.set_xlim([-25, 25])  # Adjust x limits
ax1.set_ylim([-20, 20])  # Adjust y limits
cbar1 = plt.colorbar(ax1.collections[0], ax=ax1, orientation='vertical')
cbar1.set_label('Alignment angle (º)')

# Plot the heatmap for time = 100.01
ax2.quiver(np.array(xt_100_01), np.array(yt_100_01),
           np.array(xh_100_01) - np.array(xt_100_01),
           np.array(yh_100_01) - np.array(yt_100_01),
           np.array(angle_100_01), cmap=cmap, scale=30, linewidth=30)
ax2.set_xlabel('x (A)')
ax2.set_ylabel('y (A)')
ax2.set_xlim([-30, 30])  # Adjust x limits
ax2.set_ylim([-25, 25])  # Adjust y limits
cbar2 = plt.colorbar(ax2.collections[0], ax=ax2, orientation='vertical')
cbar2.set_label('Alignment angle (º)')

# Plot the heatmap for time = 200.01
ax3.quiver(np.array(xt_100_02), np.array(yt_100_02),
           np.array(xh_100_02) - np.array(xt_100_02),
           np.array(yh_100_02) - np.array(yt_100_02),
           np.array(angle_100_02), cmap=cmap, scale=30, linewidth=30)
ax3.set_xlabel('x (A)')
ax3.set_ylabel('y (A)')
ax3.set_xlim([-25, 25])  # Adjust x limits
ax3.set_ylim([-25, 25])  # Adjust y limits
cbar3 = plt.colorbar(ax3.collections[0], ax=ax3, orientation='vertical')
cbar3.set_label('Alignment angle (º)')

# Adjust the layout and display the plot
plt.subplots_adjust(wspace=0.2)


# Save the plot figure as a .png file
plt.savefig('BOTTOM_Comparison_orientation_angle.png', dpi=800)  # Specify the filename and DPI (dots per inch)

plt.show()
